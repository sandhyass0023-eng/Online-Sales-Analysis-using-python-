# %%
#import all libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
data=pd.read_csv("/content/drive/MyDrive/datasets/archive (3)/amazon_sales_2025_INR.csv")
data
# Out:
#         Order_ID        Date Customer_ID Product_Category      Product_Name  \
# 0      ORD100000  2025-01-25    CUST2796   Home & Kitchen      Cookware Set
# 1      ORD100001  2025-08-28    CUST9669           Beauty        Hair Dryer
# 2      ORD100002  2025-02-27    CUST5808      Electronics            Tablet
# 3      ORD100003  2025-02-24    CUST5889      Electronics        Headphones
# 4      ORD100004  2025-06-15    CUST9005         Clothing             Saree
# ...          ...         ...         ...              ...               ...
# 14995  ORD114995  2025-04-12    CUST2822           Beauty          Lipstick
# 14996  ORD114996  2025-08-29    CUST6143           Beauty           Shampoo
# 14997  ORD114997  2025-01-27    CUST6747            Books  Science Textbook
# 14998  ORD114998  2025-06-21    CUST2748           Beauty        Hair Dryer
# 14999  ORD114999  2025-08-07    CUST9174   Home & Kitchen     Mixer Grinder
#
#        Quantity  Unit_Price_INR  Total_Sales_INR    Payment_Method  \
# 0             2        25574.41         51148.82       Credit Card
# 1             1        19361.41         19361.41        Debit Card
# 2             3        38476.22        115428.66  Cash on Delivery
# 3             5        38145.72        190728.60       Credit Card
# 4             5        45940.98        229704.90               UPI
# ...         ...             ...              ...               ...
# 14995         4        36421.54        145686.16               UPI
# 14996         4        18158.02         72632.08        Debit Card
# 14997         1        38864.05         38864.05               UPI
# 14998         3        32658.62         97975.86  Cash on Delivery
# 14999         5        45005.57        225027.85  Cash on Delivery
#
#       Delivery_Status  Review_Rating                 Review_Text  \
# 0            Returned              1              Waste of money
# 1            Returned              5          Excellent product!
# 2           Delivered              3                   Fair deal
# 3           Delivered              5           Highly recommend!
# 4           Delivered              5           Highly recommend!
# ...               ...            ...                         ...
# 14995       Delivered              1          Never buying again
# 14996       Delivered              4  Satisfied with the product
# 14997       Delivered              1              Waste of money
# 14998         Pending              3                Okay product
# 14999         Pending              4                Good quality
#
#                   State Country
# 0                Sikkim   India
# 1             Telangana   India
# 2              Nagaland   India
# 3                 Assam   India
# 4                Odisha   India
# ...                 ...     ...
# 14995           Gujarat   India
# 14996         Meghalaya   India
# 14997            Sikkim   India
# 14998  Himachal Pradesh   India
# 14999             Bihar   India
#
# [15000 rows x 14 columns]

# %% [markdown]
# DESCRIPTION ABOUT THE DATA:
#
# ---
#
# The Online Sales Dataset contains transactional data collected from an e-commerce platform. It records details of customer purchases made through an online website over a specific time period. The dataset helps analyze sales performance, customer's review rating and  product demand

# %%
#check data information features
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          15000 non-null  object
#  1   Date              15000 non-null  object
#  2   Customer_ID       15000 non-null  object
#  3   Product_Category  15000 non-null  object
#  4   Product_Name      15000 non-null  object
#  5   Quantity          15000 non-null  int64
#  6   Unit_Price_INR    15000 non-null  float64
#  7   Total_Sales_INR   15000 non-null  float64
#  8   Payment_Method    15000 non-null  object
#  9   Delivery_Status   15000 non-null  object
#  10  Review_Rating     15000 non-null  int64
#  11  Review_Text       15000 non-null  object
#  12  State             15000 non-null  object
#  13  Country           15000 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 1.6+ MB

# %%
#check data unique values
data.nunique()
# Out:
# Order_ID            15000
# Date                  365
# Customer_ID          7259
# Product_Category        5
# Product_Name           25
# Quantity                5
# Unit_Price_INR      14981
# Total_Sales_INR     14988
# Payment_Method          4
# Delivery_Status         3
# Review_Rating           5
# Review_Text            25
# State                  28
# Country                 1
# dtype: int64

# %% [markdown]
# SUMMARY OF FEATURES:
#
# ---
#
# The online sales dataset consists of various features that capture complete information about e-commerce transactions. It includes order details such as order ID and order date, customer information like customer ID and location, and product-related attributes including product ID, product name, and product category. The dataset also contains numerical features such as quantity sold, unit price,  total sales amount,  which help in analyzing revenue and business performance. In addition, categorical features like payment method and order status provide insights into customer preferences and delivery outcomes.
#
#
# ---

# %% [markdown]
# DATA CLEANING

# %%
#checking null values
data.isnull().sum()
# Out:
# Order_ID            0
# Date                0
# Customer_ID         0
# Product_Category    0
# Product_Name        0
# Quantity            0
# Unit_Price_INR      0
# Total_Sales_INR     0
# Payment_Method      0
# Delivery_Status     0
# Review_Rating       0
# Review_Text         0
# State               0
# Country             0
# dtype: int64

# %% [markdown]
# SUMMARY FOR NULL VALUES:
#
# ---
# From the above code,we have no null values for the features.

# %%
#checking duplicates
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#checking duplicates for ordered id
data["Order_ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
#checking duplicates for cutomer id
data["Customer_ID"].duplicated().sum()
# Out:
# np.int64(7741)

# %% [markdown]
# SUMMARY FOR DUPLICATES VALUES:
#
#
#
# ---
# From the above code ,we have no duplicate values for Order ID but we have duplicate values for Cutomer ID because same cutomer can buy the product repeatedly.

# %%
#checking the country column
a=data.groupby("Country").count()
a
# Out:
#          Order_ID   Date  Customer_ID  Product_Category  Product_Name  \
# Country
# India       15000  15000        15000             15000         15000
#
#          Quantity  Unit_Price_INR  Total_Sales_INR  Payment_Method  \
# Country
# India       15000           15000            15000           15000
#
#          Delivery_Status  Review_Rating  Review_Text  State
# Country
# India              15000          15000        15000  15000

# %%
#remove country column
a=data.drop(["Country"],axis=1)
a
# Out:
#         Order_ID        Date Customer_ID Product_Category      Product_Name  \
# 0      ORD100000  2025-01-25    CUST2796   Home & Kitchen      Cookware Set
# 1      ORD100001  2025-08-28    CUST9669           Beauty        Hair Dryer
# 2      ORD100002  2025-02-27    CUST5808      Electronics            Tablet
# 3      ORD100003  2025-02-24    CUST5889      Electronics        Headphones
# 4      ORD100004  2025-06-15    CUST9005         Clothing             Saree
# ...          ...         ...         ...              ...               ...
# 14995  ORD114995  2025-04-12    CUST2822           Beauty          Lipstick
# 14996  ORD114996  2025-08-29    CUST6143           Beauty           Shampoo
# 14997  ORD114997  2025-01-27    CUST6747            Books  Science Textbook
# 14998  ORD114998  2025-06-21    CUST2748           Beauty        Hair Dryer
# 14999  ORD114999  2025-08-07    CUST9174   Home & Kitchen     Mixer Grinder
#
#        Quantity  Unit_Price_INR  Total_Sales_INR    Payment_Method  \
# 0             2        25574.41         51148.82       Credit Card
# 1             1        19361.41         19361.41        Debit Card
# 2             3        38476.22        115428.66  Cash on Delivery
# 3             5        38145.72        190728.60       Credit Card
# 4             5        45940.98        229704.90               UPI
# ...         ...             ...              ...               ...
# 14995         4        36421.54        145686.16               UPI
# 14996         4        18158.02         72632.08        Debit Card
# 14997         1        38864.05         38864.05               UPI
# 14998         3        32658.62         97975.86  Cash on Delivery
# 14999         5        45005.57        225027.85  Cash on Delivery
#
#       Delivery_Status  Review_Rating                 Review_Text  \
# 0            Returned              1              Waste of money
# 1            Returned              5          Excellent product!
# 2           Delivered              3                   Fair deal
# 3           Delivered              5           Highly recommend!
# 4           Delivered              5           Highly recommend!
# ...               ...            ...                         ...
# 14995       Delivered              1          Never buying again
# 14996       Delivered              4  Satisfied with the product
# 14997       Delivered              1              Waste of money
# 14998         Pending              3                Okay product
# 14999         Pending              4                Good quality
#
#                   State
# 0                Sikkim
# 1             Telangana
# 2              Nagaland
# 3                 Assam
# 4                Odisha
# ...                 ...
# 14995           Gujarat
# 14996         Meghalaya
# 14997            Sikkim
# 14998  Himachal Pradesh
# 14999             Bihar
#
# [15000 rows x 13 columns]

# %% [markdown]
# SUMMARY FOR REMOVING COLUMN:
#
# From the above code ,we have only one country that is India so we remove a country column it is not necessary.

# %% [markdown]
# EXPLORATORY DATA ANALYSIS:
#
# EDA is a process of segmentation of features and segregating into groups.In this process we have segmented into CUSTOMERS BASED ANALYSIS,PRODUCT BASED ANALYSIS,PAYMENT BASED ANALYSIS AND DATE WISE ANALYSIS

# %%
#CUSTOMERS BASED ANALYSIS
#1.Which state sales more product?
a=data.groupby("State")["Product_Category"].count()
a
# Out:
# State
# Andhra Pradesh       480
# Arunachal Pradesh    519
# Assam                553
# Bihar                549
# Chhattisgarh         556
# Goa                  522
# Gujarat              504
# Haryana              518
# Himachal Pradesh     492
# Jharkhand            547
# Karnataka            539
# Kerala               510
# Madhya Pradesh       550
# Maharashtra          531
# Manipur              555
# Meghalaya            559
# Mizoram              505
# Nagaland             545
# Odisha               542
# Punjab               527
# Rajasthan            568
# Sikkim               596
# Tamil Nadu           567
# Telangana            544
# Tripura              540
# Uttar Pradesh        551
# Uttarakhand          503
# West Bengal          528
# Name: Product_Category, dtype: int64

# %%
#VISUALIZATION FOR WHICH STATE SALES MORE PRODUCT
plt.figure(figsize=(15,8))
sns.barplot(a)
plt.title("Sales of product")
plt.xlabel("State")
plt.ylabel("Product_Category")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# OBSERVATION:
#
#
# ---
#
# 1. There are 28 State in dataset
#
# 2. Sikkim has the highest product sales
#
# 3. Second highest product sales is Rajasthan
#
# 4. least product sales is Andrapradhesh

# %%
#which product has waste of money review text
a=data[data["Review_Text"]=="Waste of money"]
b=a.groupby(["Product_Category","Product_Name"])["Review_Text"].count()
b
# Out:
# Product_Category  Product_Name
# Beauty            Face Cream          18
#                   Hair Dryer          27
#                   Lipstick            23
#                   Perfume             24
#                   Shampoo             21
# Books             Biography           29
#                   Children's Book     18
#                   Comics              14
#                   Fiction Novel       19
#                   Science Textbook    22
# Clothing          Jacket              16
#                   Jeans               25
#                   Saree               26
#                   Sneakers            33
#                   T-Shirt             26
# Electronics       Headphones          27
#                   Laptop              23
#                   Smartphone          21
#                   Smartwatch          24
#                   Tablet              24
# Home & Kitchen    Air Fryer           24
#                   Cookware Set        24
#                   Mixer Grinder       31
#                   Vacuum Cleaner      11
#                   Water Purifier      23
# Name: Review_Text, dtype: int64

# %%
#which product has highly recommend review text
a=data[data["Review_Text"]=="Highly recommend!"]
b=a.groupby(["Product_Category","Product_Name"])["Review_Text"].count()
b
# Out:
# Product_Category  Product_Name
# Beauty            Face Cream          35
#                   Hair Dryer          21
#                   Lipstick            30
#                   Perfume             32
#                   Shampoo             27
# Books             Biography           17
#                   Children's Book     19
#                   Comics              26
#                   Fiction Novel       24
#                   Science Textbook    21
# Clothing          Jacket              23
#                   Jeans               21
#                   Saree               20
#                   Sneakers            24
#                   T-Shirt             28
# Electronics       Headphones          25
#                   Laptop              25
#                   Smartphone          27
#                   Smartwatch          27
#                   Tablet              27
# Home & Kitchen    Air Fryer           27
#                   Cookware Set        22
#                   Mixer Grinder       35
#                   Vacuum Cleaner      29
#                   Water Purifier      25
# Name: Review_Text, dtype: int64

# %%
#PRODUCT BASED ANALYSIS
#1.which catogry of product customer ordered most
b=data.groupby("Product_Category")["Order_ID"].count()
b
# Out:
# Product_Category
# Beauty            2997
# Books             3035
# Clothing          3022
# Electronics       3036
# Home & Kitchen    2910
# Name: Order_ID, dtype: int64

# %%
#VISUALIZATION FOR WHICH CATOGORY OF PRODUCT CUSTOMER ORDERED MOST
sns.barplot(b)
plt.title("Customer ordered most")
plt.show()

# %% [markdown]
# OBSERVERSATION
#
#
# ---
#
# 1. There are 5 product cetegory they are Beauty,Books,Clothing,Electronics,Home & kitchen.
#
# 2. Electronic product has ordered most
#
# 3. Second largest product has Books
#
# 4. Others are average compare to others

# %%
#how many customer can buy sneakers?
a=data[(data["Product_Name"]=="Sneakers")]
a
# Out:
#         Order_ID        Date Customer_ID Product_Category Product_Name  \
# 7      ORD100007  2025-08-13    CUST9479         Clothing     Sneakers
# 20     ORD100020  2025-01-05    CUST8508         Clothing     Sneakers
# 64     ORD100064  2025-04-09    CUST4545         Clothing     Sneakers
# 108    ORD100108  2025-10-06    CUST6876         Clothing     Sneakers
# 134    ORD100134  2025-09-29    CUST9355         Clothing     Sneakers
# ...          ...         ...         ...              ...          ...
# 14916  ORD114916  2025-11-22    CUST7719         Clothing     Sneakers
# 14940  ORD114940  2025-12-22    CUST9272         Clothing     Sneakers
# 14966  ORD114966  2025-08-09    CUST9567         Clothing     Sneakers
# 14981  ORD114981  2025-05-27    CUST2859         Clothing     Sneakers
# 14991  ORD114991  2025-05-20    CUST9945         Clothing     Sneakers
#
#        Quantity  Unit_Price_INR  Total_Sales_INR    Payment_Method  \
# 7             4        49758.44        199033.76  Cash on Delivery
# 20            4        15945.62         63782.48               UPI
# 64            1        37195.48         37195.48  Cash on Delivery
# 108           1        49050.20         49050.20               UPI
# 134           2         4003.69          8007.38       Credit Card
# ...         ...             ...              ...               ...
# 14916         2        33527.96         67055.92               UPI
# 14940         4         5171.33         20685.32        Debit Card
# 14966         5        24187.67        120938.35               UPI
# 14981         5        28001.53        140007.65  Cash on Delivery
# 14991         2         7037.59         14075.18       Credit Card
#
#       Delivery_Status  Review_Rating         Review_Text           State  \
# 7           Delivered              3        Okay product  Andhra Pradesh
# 20          Delivered              1  Never buying again     Maharashtra
# 64            Pending              2      Poor packaging         Gujarat
# 108           Pending              3     Could be better       Karnataka
# 134           Pending              1      Defective item         Haryana
# ...               ...            ...                 ...             ...
# 14916         Pending              2      Poor packaging       Jharkhand
# 14940         Pending              3           Fair deal  Andhra Pradesh
# 14966         Pending              4        Good quality   Uttar Pradesh
# 14981        Returned              3     Could be better      Tamil Nadu
# 14991        Returned              3           Fair deal       Karnataka
#
#       Country
# 7       India
# 20      India
# 64      India
# 108     India
# 134     India
# ...       ...
# 14916   India
# 14940   India
# 14966   India
# 14981   India
# 14991   India
#
# [596 rows x 14 columns]

# %%
# 2.  which type of product can have more review rate?
review=data.groupby("Product_Name")["Review_Rating"].count()
review
# Out:
# Product_Name
# Air Fryer           614
# Biography           579
# Children's Book     636
# Comics              597
# Cookware Set        577
# Face Cream          596
# Fiction Novel       599
# Hair Dryer          599
# Headphones          610
# Jacket              601
# Jeans               604
# Laptop              618
# Lipstick            590
# Mixer Grinder       582
# Perfume             629
# Saree               598
# Science Textbook    624
# Shampoo             583
# Smartphone          577
# Smartwatch          615
# Sneakers            596
# T-Shirt             623
# Tablet              616
# Vacuum Cleaner      567
# Water Purifier      570
# Name: Review_Rating, dtype: int64

# %%
#VISUALIZATION FOR WHICH TYPE OF PRODUCT CAN HAVE MORE REVIEW RATE
sns.lineplot(review)
plt.title("High review rate")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# OBSERVATION:
#
#
# ---
# 1. There are 25 product in dataset
#
# 1. Children's book has the highest review rate
#
# 2. Vacuum cleaner has the most lowest review rate
#
# 3. Others are average review rate

# %%
#3. Which type of product can customer ordered highest?
highest_order=data.groupby("Product_Category")["Quantity"].count()
highest_order
# Out:
# Product_Category
# Beauty            2997
# Books             3035
# Clothing          3022
# Electronics       3036
# Home & Kitchen    2910
# Name: Quantity, dtype: int64

# %%
#VISUALIZATION FOR WHICH TYPE OF PRODUCT CAN CUSTOMER ORDERED HIGHEST
sns.scatterplot(highest_order)
plt.title("Highest quantity of product")
plt.show()

# %% [markdown]
# OBSERVATION:
#
#
# ---
#
# 1. Compare to others Books and Electronic thus customer ordered highest
#
# 2. Home & Kitchen have least ordered
#
# 3. Beauty & Clothing have avarage ordered

# %%
#4. which product has high price?
high_price=data.groupby("Product_Name")["Unit_Price_INR"].max()
high_price
# Out:
# Product_Name
# Air Fryer           49916.82
# Biography           49840.15
# Children's Book     49824.23
# Comics              49982.97
# Cookware Set        49957.20
# Face Cream          49897.75
# Fiction Novel       49898.76
# Hair Dryer          49937.45
# Headphones          49847.68
# Jacket              49972.29
# Jeans               49970.67
# Laptop              49981.88
# Lipstick            49869.28
# Mixer Grinder       49664.09
# Perfume             49920.36
# Saree               49854.52
# Science Textbook    49863.79
# Shampoo             49973.84
# Smartphone          49869.62
# Smartwatch          49923.48
# Sneakers            49994.43
# T-Shirt             49885.78
# Tablet              49475.26
# Vacuum Cleaner      49862.08
# Water Purifier      49991.10
# Name: Unit_Price_INR, dtype: float64

# %%
#VISUALIZATION FOR HIGHEST PRODUCT PRICE
plt.figure(figsize=(10,5))
sns.scatterplot(high_price)
plt.title("High price of the product")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# OBSERVATION:
#
#
# ---
# 1. Sneakers has highest unit price
#
# 2. Waterpurifier  also have high unit price compare to others
#
# 3. Mixer grinder has most least unit price
#
# 4. Others are average

# %%
#5.which product has have low total sales?
total_sale=data.groupby("Product_Category")["Total_Sales_INR"].sum()
total_sale
# Out:
# Product_Category
# Beauty            2.274896e+08
# Books             2.249992e+08
# Clothing          2.224093e+08
# Electronics       2.265649e+08
# Home & Kitchen    2.166987e+08
# Name: Total_Sales_INR, dtype: float64

# %%
#VISUALIZATION FOR LOW TOTAL SALE
sns.barplot(total_sale)
plt.title("Low total sales")
plt.show()

# %% [markdown]
# OBSERVATION:
#
#
# ---
#
# 1. Home & Kitchen has the lowest total sale
#
# 2. Electronics has highest total sale
#
# 3. Others are average

# %%
#6.which product has most fair deal
review=data.groupby("Review_Text").get_group("Fair deal")
a=review.groupby("Product_Category")["Review_Text"].count()
a
# Out:
# Product_Category
# Beauty            122
# Books             108
# Clothing          132
# Electronics       100
# Home & Kitchen    118
# Name: Review_Text, dtype: int64

# %%
#VISUALIZATION FOR MOST FAIR PRODUCT
sns.barplot(a)
plt.title("Most fair deal review")
plt.show()

# %% [markdown]
# OBSERVATION
#
#
# ---
# 1. There are 5 product in dataset they are Beauty , Books , Clothing , Electronics , Home & Kitchen
#
# 2. Clothing product has the most fair deal
#
# 3. Electronics product has least fair deal

# %%
#7. How many clothing product can sold above 5 quantity
sales=data[(data["Product_Category"]=="Clothing")&(data["Quantity"]==5)]
a=sales.groupby("Product_Category")["Quantity"].count()
a
# Out:
# Product_Category
# Clothing    577
# Name: Quantity, dtype: int64

# %% [markdown]
# OBSERVATION
#
#
# ---
#
# 1. 577 Quantity of clothing product has sold

# %%
#8. How many home & kitchen product has above 5 review rate?
review=data[(data["Product_Category"]=="Home & Kitchen")&(data["Review_Rating"]==5)]
a=review.groupby("Product_Category")["Review_Rating"].count()
a
# Out:
# Product_Category
# Home & Kitchen    625
# Name: Review_Rating, dtype: int64

# %% [markdown]
# OBSERVATION
#
#
# ---
# 1. 625 Home & Kitchen product has above 5 review rate

# %%
#PAYMENT BASED ANALYSIS
#1.how many customer can purchase the product through upi?
payment=data.groupby("Payment_Method").get_group("UPI")
a=payment.groupby("Payment_Method").count()
a
# Out:
#                 Order_ID  Date  Customer_ID  Product_Category  Product_Name  \
# Payment_Method
# UPI                 3646  3646         3646              3646          3646
#
#                 Quantity  Unit_Price_INR  Total_Sales_INR  Delivery_Status  \
# Payment_Method
# UPI                 3646            3646             3646             3646
#
#                 Review_Rating  Review_Text  State  Country
# Payment_Method
# UPI                      3646         3646   3646     3646

# %% [markdown]
# OBSERVATION
#
#
# ---
#
# 1. 3646 customers can purchase the product through upi

# %%
#2.how many product can delivered and return ?
a=data.groupby("Delivery_Status")["Delivery_Status"].count()
a
# Out:
# Delivery_Status
# Delivered    5075
# Pending      5044
# Returned     4881
# Name: Delivery_Status, dtype: int64

# %% [markdown]
# OBSERVERTION
#
#
# ---
#
# 1. 5075 Product has delivered
#
# 2. 4881 product has returned
#
# 3. 5044 product has pending

# %%
#how many  product are pending?
a=data[data["Delivery_Status"]=="Pending"]
b=a.groupby(["Product_Category","Product_Name"])["Delivery_Status"].count()
b
# Out:
# Product_Category  Product_Name
# Beauty            Face Cream          190
#                   Hair Dryer          210
#                   Lipstick            191
#                   Perfume             189
#                   Shampoo             191
# Books             Biography           197
#                   Children's Book     224
#                   Comics              170
#                   Fiction Novel       200
#                   Science Textbook    198
# Clothing          Jacket              211
#                   Jeans               213
#                   Saree               213
#                   Sneakers            202
#                   T-Shirt             210
# Electronics       Headphones          187
#                   Laptop              220
#                   Smartphone          193
#                   Smartwatch          200
#                   Tablet              223
# Home & Kitchen    Air Fryer           194
#                   Cookware Set        214
#                   Mixer Grinder       188
#                   Vacuum Cleaner      198
#                   Water Purifier      218
# Name: Delivery_Status, dtype: int64

# %%
#3. how many product can have excellent review rate
review=data.groupby("Review_Text").get_group("Excellent product!")
review.groupby("Review_Text").count()

# %% [markdown]
# OBSERVATION
#
#
# ---
#
# 1. 653 products are excellent review rate

# %%
# 4 how many beauty product has return ?
beauty=data.groupby("Product_Category").get_group("Beauty")
a=beauty.groupby("Delivery_Status").get_group("Returned")
b=a.groupby("Product_Category")["Delivery_Status"].count()
b

# %% [markdown]
# OBSERVATION
#
#
# ---
#
# 1. 954 Beauty product has return

# %%
#5.Which product have the highest return rate?
a=data.groupby("Delivery_Status").get_group("Returned")
b=a.groupby("Product_Category")["Delivery_Status"].count()
b
# Out:
# Product_Category
# Beauty             954
# Books             1029
# Clothing           982
# Electronics       1006
# Home & Kitchen     910
# Name: Delivery_Status, dtype: int64

# %%
#VISUALIZATION FOR WHICH PRODUCT HAVE THE HIGHEST RETURN RATE
sns.barplot(b)
plt.title("Highest return rate")
plt.show()

# %% [markdown]
# OBSERVATION
#
#
# ---
# 1. 1029 Books were  returned
#
# 2. Second highest 1006 Electronics were returned

# %%
#6. Which payment method is used most frequently?
payment=data.groupby("Payment_Method")["Payment_Method"].count()
payment
# Out:
# Payment_Method
# Cash on Delivery    3827
# Credit Card         3800
# Debit Card          3727
# UPI                 3646
# Name: Payment_Method, dtype: int64

# %%
#VISUALIZATION FOR WHICH PAYMENT METHOD IS USED MOST FREQUENTLY
plt.barh(payment.index,payment.values)
plt.xlabel("Payment count")
plt.ylabel("Payment_method")
plt.title("Most frequent payment method")
plt.show()

# %% [markdown]
# OBSERVATION
#
#
# ---
# 1. Most frequent payment method is cash on delivery
#
# 2. 3827 Customer pay cash on delivery
#
# 3. 3800 Customer pay through credit card
#
# 4. 3727 Customer pay through debit card
#
# 5. 3646 Customer pay through upi

# %%
#7. What is the total sales for each payment method ?
sales=data.groupby("Payment_Method")["Total_Sales_INR"].sum()
sales
# Out:
# Payment_Method
# Cash on Delivery    2.865114e+08
# Credit Card         2.868892e+08
# Debit Card          2.730366e+08
# UPI                 2.717245e+08
# Name: Total_Sales_INR, dtype: float64

# %%
#VISUALIZATION FOR TOTAL SALES FOR EACH PAYMENT METHOD
sns.barplot(sales)
plt.title("Total sales for each payment method")
plt.show()

# %% [markdown]
# OBSERVATION
#
#
# ---
#
# 1. Cash on delivery has the high total sales
#
# 2. Credit card has the second largest total sales compare to others
#
# 3. UPI has least total sales

# %%
#REGION BASED ANALYSIS
#1. How many lipstick product can delivered in sikkim
sales=data[(data["Product_Name"]=="Lipstick")&(data["State"]=="Sikkim")&(data["Delivery_Status"]=="Delivered")]
a=sales.groupby("Product_Name")["Delivery_Status"].count()
a

# %% [markdown]
# OBSERVATION
#
#
# ---
#
# 1. 12 Lipstick product can delivered in sikkim state

# %%
#2.how many product can sold in assam ?
sales=data.groupby("State").get_group("Assam")
a=sales.groupby("State")["Total_Sales_INR"].count()
a

# %% [markdown]
# OBSERVATION
#
#
# ---
#
# 1. 553 product has sold in Assam

# %%
#3.How many electronics products are sales in tamilnadu?
a=data[(data['State']=="Tamil Nadu")&(data["Product_Category"]=="Electronics")]
b=a.groupby("State")["Product_Category"].count()
b

# %% [markdown]
# OBSERVATION
#
#
# ---
#
# 1. 115 Electronic product has sold in Tamilnadu

# %%
#DATE WISE ANALYSIS
#1.how many product can sold in same date ?
a=data.groupby("Product_Category")["Date"].count()
a
# Out:
# Product_Category
# Beauty            2997
# Books             3035
# Clothing          3022
# Electronics       3036
# Home & Kitchen    2910
# Name: Date, dtype: int64

# %%
sns.barplot(a)
plt.title("Sold in same date")
plt.show()

# %% [markdown]
# OBSERVATION
#
#
# ---
#
# 1. 2997  Beauty Product can sold in same date
#
# 2. 3035 Books product can sold in same date
#
# 3. 3022 Clothing product can sold in same date
#
# 4. 3036 Electronic product can sold in same date
#
# 5. 2910 Home & Kitchen product can sold in same date
